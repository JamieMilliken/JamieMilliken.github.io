# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
import time
import random

# %%
BOROUGHS = {
    "City of London": "5E61224",
    "Barking and Dagenham": "5E61400",
    "Barnet": "5E93929",
    "Bexley": "5E93932",
    "Brent": "5E93935",
    "Bromley": "5E93938",
    "Camden": "5E93941",
    "Croydon": "5E93944",
    "Ealing": "5E93947",
    "Enfield": "5E93950",
    "Greenwich": "5E61226",
    "Hackney": "5E93953",
    "Hammersmith and Fulham": "5E61407",
    "Haringey": "5E61227",
    "Harrow": "5E93956",
    "Havering": "5E61228",
    "Hillingdon": "5E93959",
    "Hounslow": "5E93962",
    "Islington": "5E93965",
    "Kensington and Chelsea": "5E61229",
    "Kingston upon Thames": "5E93968",
    "Lambeth": "5E93971",
    "Lewisham": "5E61413",
    "Merton": "5E61414",
    "Newham": "5E61231",
    "Redbridge": "5E61537",
    "Richmond upon Thames": "5E61415",
    "Southwark": "5E61518",
    "Sutton": "5E93974",
    "Tower Hamlets": "5E61417",
    "Waltham Forest": "5E61232",
    "Wandsworth": "5E93977",
    "Westminster": "5E93980",
}

# %%
all_apartment_links = [] # stores apartment links
all_description = [] # stores number of bedrooms in the apartment
all_address = [] # stores address of apartment
all_price = [] # stores the listing price of apartment
all_geoson = [] #stores the geoson of the listing

# %%
def main():

    for borough in list(BOROUGHS.values()):

        # initialise index, this tracks the page number we are on. every additional page adds 24 to the index
        index = 0

        key = [key for key, value in BOROUGHS.items() if value == borough]
        print(f"We are scraping the borough named: {key}")
        for pages in range(41):

            # define our user headers
            headers = {
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.114 Safari/537.36"
            }

            # the website changes if the you are on page 1 as compared to other pages
            if index == 0:
                rightmove = f"https://www.rightmove.co.uk/property-for-sale/find.html?locationIdentifier=REGION%{borough}&sortType=6&propertyTypes=&includeSSTC=false&mustHave=&dontShow=&furnishTypes=&keywords="

            elif index != 0:
                rightmove = f"https://www.rightmove.co.uk/property-for-sale/find.html?locationIdentifier=REGION%{borough}&sortType=6&index={index}&propertyTypes=&includeSSTC=false&mustHave=&dontShow=&furnishTypes=&keywords="

            # request our webpage
            res = requests.get(rightmove, headers=headers)

            # check status
            res.raise_for_status()

            soup = BeautifulSoup(res.text, "html.parser")
            # This gets the list of apartments
            apartments = soup.find_all("div", class_="l-searchResult is-list")

                # This gets the number of listings
            number_of_listings = soup.find(
                    "span", {"class": "searchHeader-resultCount"}
                )
            number_of_listings = number_of_listings.get_text()
            number_of_listings = int(number_of_listings.replace(",", ""))

            for i in range(len(apartments)):

                # tracks which apartment we are on in the page
                apartment_no = apartments[i]

                # append link
                apartment_info = apartment_no.find("a", class_="propertyCard-link")
                link = "https://www.rightmove.co.uk" + apartment_info.attrs["href"]
                all_apartment_links.append(link)

                # append address
                address = (
                    apartment_info.find("address", class_="propertyCard-address")
                    .get_text()
                    .strip()
                )
                all_address.append(address)

                # append description
                description = (
                    apartment_info.find("h2", class_="propertyCard-title")
                    .get_text()
                    .strip()
                    )
                all_description.append(description)

                # append price
                price = (
                    apartment_no.find("div", class_="propertyCard-priceValue")
                    .get_text()
                    .strip()
                )

            
                all_price.append(price)

            print(f"You have scrapped {pages + 1} pages of apartment listings.")
            print(f"You have {number_of_listings - index} listings left to go")
            print("\n")

            # code to ensure that we do not overwhelm the website
            time.sleep(random.randint(1, 3))

            # Code to count how many listings we have scrapped already.
            index = index + 24

            if index >= number_of_listings:
                break
            # convert data to dataframe
        data = {
            "Links": all_apartment_links,
            "Address": all_address,
            "Description": all_description,
            "Price": all_price,
        }
        df = pd.DataFrame.from_dict(data)
        df.to_csv(r"rightmove_data.csv", encoding="utf-8", header="true", index = False)


if __name__ == "__main__":
    main()
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
# You have scrapped 28 pages of apartment listings.
# You have 2164 listings left to go
#
#
# You have scrapped 29 pages of apartment listings.
# You have 2138 listings left to go
#
#
# You have scrapped 30 pages of apartment listings.
# You have 2116 listings left to go
#
#
# You have scrapped 31 pages of apartment listings.
# You have 2093 listings left to go
#
#
# You have scrapped 32 pages of apartment listings.
# You have 2068 listings left to go
#
#
# You have scrapped 33 pages of apartment listings.
# You have 2044 listings left to go
#
#
# You have scrapped 34 pages of apartment listings.
# You have 2018 listings left to go
#
#
# You have scrapped 35 pages of apartment listings.
# You have 1994 listings left to go
#
#
# You have scrapped 36 pages of apartment listings.
# You have 1972 listings left to go
#
#
# You have scrapped 37 pages of apartment listings.
# You have 1946 listings left to go
#
#
# You have scrapped 38 pages of apartment listings.
# You have 1922 listings left to go
#
#
# You have scrapped 39 pages of apartment listings.
# You have 1900 listings left to go
#
#
# You have scrapped 40 pages of apartment listings.
# You have 1877 listings left to go
#
#
# You have scrapped 41 pages of apartment listings.
# You have 1853 listings left to go
#
#
# We are scraping the borough named: ['Bexley']
# You have scrapped 1 pages of apartment listings.
# You have 923 listings left to go
#
#
# You have scrapped 2 pages of apartment listings.
# You have 899 listings left to go
#
#
# You have scrapped 3 pages of apartment listings.
# You have 874 listings left to go
#
#
# You have scrapped 4 pages of apartment listings.
# You have 851 listings left to go
#
#
# You have scrapped 5 pages of apartment listings.
# You have 827 listings left to go
#
#
# You have scrapped 6 pages of apartment listings.
# You have 803 listings left to go
#
#
# You have scrapped 7 pages of apartment listings.
# You have 778 listings left to go
#
#
# You have scrapped 8 pages of apartment listings.
# You have 755 listings left to go
#
#
# You have scrapped 9 pages of apartment listings.
# You have 731 listings left to go
#
#
# You have scrapped 10 pages of apartment listings.
# You have 707 listings left to go
#
#
# You have scrapped 11 pages of apartment listings.
# You have 683 listings left to go
#
#
# You have scrapped 12 pages of apartment listings.
# You have 659 listings left to go
#
#
# You have scrapped 13 pages of apartment listings.
# You have 635 listings left to go
#
#
# You have scrapped 14 pages of apartment listings.
# You have 611 listings left to go
#
#
# You have scrapped 15 pages of apartment listings.
# You have 587 listings left to go
#
#
# You have scrapped 16 pages of apartment listings.
# You have 563 listings left to go
#
#
# You have scrapped 17 pages of apartment listings.
# You have 539 listings left to go
#
#
# You have scrapped 18 pages of apartment listings.
# You have 515 listings left to go
#
#
# You have scrapped 19 pages of apartment listings.
# You have 491 listings left to go
#
#
# You have scrapped 20 pages of apartment listings.
# You have 467 listings left to go
#
#
# You have scrapped 21 pages of apartment listings.
# You have 442 listings left to go
#
#
# You have scrapped 22 pages of apartment listings.
# You have 418 listings left to go
#
#
# You have scrapped 23 pages of apartment listings.
# You have 395 listings left to go
#
#
# You have scrapped 24 pages of apartment listings.
# You have 371 listings left to go
#
#
# You have scrapped 25 pages of apartment listings.
# You have 347 listings left to go
#
#
# You have scrapped 26 pages of apartment listings.
# You have 322 listings left to go
#
#
# You have scrapped 27 pages of apartment listings.
# You have 298 listings left to go
#
#
# You have scrapped 28 pages of apartment listings.
# You have 274 listings left to go
#
#
# You have scrapped 29 pages of apartment listings.
# You have 251 listings left to go
#
#
# You have scrapped 30 pages of apartment listings.
# You have 226 listings left to go
#
#
# You have scrapped 31 pages of apartment listings.
# You have 202 listings left to go
#
#
# You have scrapped 32 pages of apartment listings.
# You have 179 listings left to go
#
#
# You have scrapped 33 pages of apartment listings.
# You have 154 listings left to go
#
#
# You have scrapped 34 pages of apartment listings.
# You have 130 listings left to go
#
#
# You have scrapped 35 pages of apartment listings.
# You have 106 listings left to go
#
#
# You have scrapped 36 pages of apartment listings.
# You have 83 listings left to go
#
#
# You have scrapped 37 pages of apartment listings.
# You have 58 listings left to go
#
#
# You have scrapped 38 pages of apartment listings.
# You have 35 listings left to go
#
#
# You have scrapped 39 pages of apartment listings.
# You have 10 listings left to go
#
#
# We are scraping the borough named: ['Brent']
# You have scrapped 1 pages of apartment listings.
# You have 1916 listings left to go
#
#
# You have scrapped 2 pages of apartment listings.
# You have 1893 listings left to go
#
#
# You have scrapped 3 pages of apartment listings.
# You have 1868 listings left to go
#
#
# You have scrapped 4 pages of apartment listings.
# You have 1844 listings left to go
#
#
# You have scrapped 5 pages of apartment listings.
# You have 1821 listings left to go
#
#
# You have scrapped 6 pages of apartment listings.
# You have 1797 listings left to go
#
#
# You have scrapped 7 pages of apartment listings.
# You have 1772 listings left to go
#
#
# You have scrapped 8 pages of apartment listings.
# You have 1748 listings left to go
#
#
# You have scrapped 9 pages of apartment listings.
# You have 1724 listings left to go
#
#
# You have scrapped 10 pages of apartment listings.
# You have 1700 listings left to go
#
#
# You have scrapped 11 pages of apartment listings.
# You have 1676 listings left to go
#
#
# You have scrapped 12 pages of apartment listings.
# You have 1652 listings left to go
#
#
# You have scrapped 13 pages of apartment listings.
# You have 1628 listings left to go
#
#
# You have scrapped 14 pages of apartment listings.
# You have 1604 listings left to go
#
#
# You have scrapped 15 pages of apartment listings.
# You have 1581 listings left to go
#
#
# You have scrapped 16 pages of apartment listings.
# You have 1556 listings left to go
#
#
# You have scrapped 17 pages of apartment listings.
# You have 1533 listings left to go
#
#
# You have scrapped 18 pages of apartment listings.
# You have 1509 listings left to go
#
#
# You have scrapped 19 pages of apartment listings.
# You have 1484 listings left to go
#
#
# You have scrapped 20 pages of apartment listings.
# You have 1460 listings left to go
#
#
# You have scrapped 21 pages of apartment listings.
# You have 1436 listings left to go
#
#
# You have scrapped 22 pages of apartment listings.
# You have 1412 listings left to go
#
#
# You have scrapped 23 pages of apartment listings.
# You have 1388 listings left to go
#
#
# You have scrapped 24 pages of apartment listings.
# You have 1364 listings left to go
#
#
# You have scrapped 25 pages of apartment listings.
# You have 1340 listings left to go
#
#
# You have scrapped 26 pages of apartment listings.
# You have 1316 listings left to go
#
#
# You have scrapped 27 pages of apartment listings.
# You have 1293 listings left to go
#
#
# You have scrapped 28 pages of apartment listings.
# You have 1268 listings left to go
#
#
# You have scrapped 29 pages of apartment listings.
# You have 1244 listings left to go
#
#
# You have scrapped 30 pages of apartment listings.
# You have 1220 listings left to go
#
#
# You have scrapped 31 pages of apartment listings.
# You have 1196 listings left to go
#
#
# You have scrapped 32 pages of apartment listings.
# You have 1173 listings left to go
#
#
# You have scrapped 33 pages of apartment listings.
# You have 1148 listings left to go
#
#
# You have scrapped 34 pages of apartment listings.
# You have 1125 listings left to go
#
#
# You have scrapped 35 pages of apartment listings.
# You have 1100 listings left to go
#
#
# You have scrapped 36 pages of apartment listings.
# You have 1077 listings left to go
#
#
# You have scrapped 37 pages of apartment listings.
# You have 1053 listings left to go
#
#
# You have scrapped 38 pages of apartment listings.
# You have 1028 listings left to go
#
#
# You have scrapped 39 pages of apartment listings.
# You have 1004 listings left to go
#
#
# You have scrapped 40 pages of apartment listings.
# You have 980 listings left to go
#
#
# You have scrapped 41 pages of apartment listings.
# You have 957 listings left to go
#
#
# We are scraping the borough named: ['Bromley']
# You have scrapped 1 pages of apartment listings.
# You have 1870 listings left to go
#
#
# You have scrapped 2 pages of apartment listings.
# You have 1846 listings left to go
#
#
# You have scrapped 3 pages of apartment listings.
# You have 1822 listings left to go
#
#
# You have scrapped 4 pages of apartment listings.
# You have 1798 listings left to go
#
#
# You have scrapped 5 pages of apartment listings.
# You have 1774 listings left to go
#
#
# You have scrapped 6 pages of apartment listings.
# You have 1750 listings left to go
#
#
# You have scrapped 7 pages of apartment listings.
# You have 1726 listings left to go
#
#
# You have scrapped 8 pages of apartment listings.
# You have 1702 listings left to go
#
#
# You have scrapped 9 pages of apartment listings.
# You have 1678 listings left to go
#
#
# You have scrapped 10 pages of apartment listings.
# You have 1654 listings left to go
#
#
# You have scrapped 11 pages of apartment listings.
# You have 1630 listings left to go
#
#
# You have scrapped 12 pages of apartment listings.
# You have 1606 listings left to go
#
#
# You have scrapped 13 pages of apartment listings.
# You have 1582 listings left to go
#
#
# You have scrapped 14 pages of apartment listings.
# You have 1558 listings left to go
#
#
# You have scrapped 15 pages of apartment listings.
# You have 1534 listings left to go
#
#
# You have scrapped 16 pages of apartment listings.
# You have 1510 listings left to go
#
#
# You have scrapped 17 pages of apartment listings.
# You have 1486 listings left to go
#
#
# You have scrapped 18 pages of apartment listings.
# You have 1462 listings left to go
#
#
# You have scrapped 19 pages of apartment listings.
# You have 1438 listings left to go
#
#
# You have scrapped 20 pages of apartment listings.
# You have 1414 listings left to go
#
#
# You have scrapped 21 pages of apartment listings.
# You have 1390 listings left to go
#
#
# You have scrapped 22 pages of apartment listings.
# You have 1366 listings left to go
#
#
# You have scrapped 23 pages of apartment listings.
# You have 1342 listings left to go
#
#
# You have scrapped 24 pages of apartment listings.
# You have 1318 listings left to go
#
#
# You have scrapped 25 pages of apartment listings.
# You have 1294 listings left to go
#
#
# You have scrapped 26 pages of apartment listings.
# You have 1270 listings left to go
#
#
# You have scrapped 27 pages of apartment listings.
# You have 1246 listings left to go
#
#
# You have scrapped 28 pages of apartment listings.
# You have 1222 listings left to go
#
#
# You have scrapped 29 pages of apartment listings.
# You have 1198 listings left to go
#
#
# You have scrapped 30 pages of apartment listings.
# You have 1174 listings left to go
#
#
# You have scrapped 31 pages of apartment listings.
# You have 1150 listings left to go
#
#
# You have scrapped 32 pages of apartment listings.
# You have 1126 listings left to go
#
#
# You have scrapped 33 pages of apartment listings.
# You have 1102 listings left to go
#
#
# You have scrapped 34 pages of apartment listings.
# You have 1078 listings left to go
#
#
# You have scrapped 35 pages of apartment listings.
# You have 1054 listings left to go
#
#
# You have scrapped 36 pages of apartment listings.
# You have 1030 listings left to go
#
#
# You have scrapped 37 pages of apartment listings.
# You have 1006 listings left to go
#
#
# You have scrapped 38 pages of apartment listings.
# You have 982 listings left to go
#
#
# You have scrapped 39 pages of apartment listings.
# You have 958 listings left to go
#
#
# You have scrapped 40 pages of apartment listings.
# You have 934 listings left to go
#
#
# You have scrapped 41 pages of apartment listings.
# You have 910 listings left to go
#
#
# We are scraping the borough named: ['Camden']
# You have scrapped 1 pages of apartment listings.
# You have 1916 listings left to go
#
#
# You have scrapped 2 pages of apartment listings.
# You have 1893 listings left to go
#
#
# You have scrapped 3 pages of apartment listings.
# You have 1869 listings left to go
#
#
# You have scrapped 4 pages of apartment listings.
# You have 1845 listings left to go
#
#
# You have scrapped 5 pages of apartment listings.
# You have 1821 listings left to go
#
#
# You have scrapped 6 pages of apartment listings.
# You have 1797 listings left to go
#
#
# You have scrapped 7 pages of apartment listings.
# You have 1772 listings left to go
#
#
# You have scrapped 8 pages of apartment listings.
# You have 1749 listings left to go
#
#
# You have scrapped 9 pages of apartment listings.
# You have 1725 listings left to go
#
#
# You have scrapped 10 pages of apartment listings.
# You have 1701 listings left to go
#
#
# You have scrapped 11 pages of apartment listings.
# You have 1676 listings left to go
#
#
# You have scrapped 12 pages of apartment listings.
# You have 1653 listings left to go
#
#
# You have scrapped 13 pages of apartment listings.
# You have 1629 listings left to go
#
#
# You have scrapped 14 pages of apartment listings.
# You have 1605 listings left to go
#
#
# You have scrapped 15 pages of apartment listings.
# You have 1581 listings left to go
#
#
# You have scrapped 16 pages of apartment listings.
# You have 1556 listings left to go
#
#
# You have scrapped 17 pages of apartment listings.
# You have 1532 listings left to go
#
#
# You have scrapped 18 pages of apartment listings.
# You have 1509 listings left to go
#
#
# You have scrapped 19 pages of apartment listings.
# You have 1484 listings left to go
#
#
# You have scrapped 20 pages of apartment listings.
# You have 1461 listings left to go
#
#
# You have scrapped 21 pages of apartment listings.
# You have 1436 listings left to go
#
#
# You have scrapped 22 pages of apartment listings.
# You have 1413 listings left to go
#
#
# You have scrapped 23 pages of apartment listings.
# You have 1388 listings left to go
#
#
# You have scrapped 24 pages of apartment listings.
# You have 1365 listings left to go
#
#
# You have scrapped 25 pages of apartment listings.
# You have 1340 listings left to go
#
#
# You have scrapped 26 pages of apartment listings.
# You have 1316 listings left to go
#
#
# You have scrapped 27 pages of apartment listings.
# You have 1293 listings left to go
#
#
# You have scrapped 28 pages of apartment listings.
# You have 1268 listings left to go
#
#
# You have scrapped 29 pages of apartment listings.
# You have 1244 listings left to go
#
#
# You have scrapped 30 pages of apartment listings.
# You have 1220 listings left to go
#
#
# You have scrapped 31 pages of apartment listings.
# You have 1197 listings left to go
#
#
# You have scrapped 32 pages of apartment listings.
# You have 1173 listings left to go
#
#
# You have scrapped 33 pages of apartment listings.
# You have 1150 listings left to go
#
#
# You have scrapped 34 pages of apartment listings.
# You have 1126 listings left to go
#
#
# You have scrapped 35 pages of apartment listings.
# You have 1102 listings left to go
#
#
# You have scrapped 36 pages of apartment listings.
# You have 1078 listings left to go
#
#
# You have scrapped 37 pages of apartment listings.
# You have 1054 listings left to go
#
#
# You have scrapped 38 pages of apartment listings.
# You have 1030 listings left to go
#
#
# You have scrapped 39 pages of apartment listings.
# You have 1005 listings left to go
#
#
# You have scrapped 40 pages of apartment listings.
# You have 982 listings left to go
#
#
# You have scrapped 41 pages of apartment listings.
# You have 958 listings left to go
#
#
# We are scraping the borough named: ['Croydon']
# You have scrapped 1 pages of apartment listings.
# You have 2711 listings left to go
#
#
# You have scrapped 2 pages of apartment listings.
# You have 2688 listings left to go
#
#
# You have scrapped 3 pages of apartment listings.
# You have 2663 listings left to go
#
#
# You have scrapped 4 pages of apartment listings.
# You have 2640 listings left to go
#
#
# You have scrapped 5 pages of apartment listings.
# You have 2615 listings left to go
#
#
# You have scrapped 6 pages of apartment listings.
# You have 2592 listings left to go
#
#
# You have scrapped 7 pages of apartment listings.
# You have 2568 listings left to go
#
#
# You have scrapped 8 pages of apartment listings.
# You have 2543 listings left to go
#
#
# You have scrapped 9 pages of apartment listings.
# You have 2520 listings left to go
#
#
# You have scrapped 10 pages of apartment listings.
# You have 2496 listings left to go
#
#
# You have scrapped 11 pages of apartment listings.
# You have 2472 listings left to go
#
#
# You have scrapped 12 pages of apartment listings.
# You have 2447 listings left to go
#
#
# You have scrapped 13 pages of apartment listings.
# You have 2423 listings left to go
#
#
# You have scrapped 14 pages of apartment listings.
# You have 2399 listings left to go
#
#
# You have scrapped 15 pages of apartment listings.
# You have 2376 listings left to go
#
#
# You have scrapped 16 pages of apartment listings.
# You have 2351 listings left to go
#
#
# You have scrapped 17 pages of apartment listings.
# You have 2328 listings left to go
#
#
# You have scrapped 18 pages of apartment listings.
# You have 2303 listings left to go
#
#
# You have scrapped 19 pages of apartment listings.
# You have 2280 listings left to go
#
#
# You have scrapped 20 pages of apartment listings.
# You have 2255 listings left to go
#
#
# You have scrapped 21 pages of apartment listings.
# You have 2231 listings left to go
#
#
# You have scrapped 22 pages of apartment listings.
# You have 2208 listings left to go
#
#
# You have scrapped 23 pages of apartment listings.
# You have 2184 listings left to go
#
#
# You have scrapped 24 pages of apartment listings.
# You have 2160 listings left to go
#
#
# You have scrapped 25 pages of apartment listings.
# You have 2135 listings left to go
#
#
# You have scrapped 26 pages of apartment listings.
# You have 2112 listings left to go
#
#
# You have scrapped 27 pages of apartment listings.
# You have 2088 listings left to go
#
#
# You have scrapped 28 pages of apartment listings.
# You have 2063 listings left to go
#
#
# You have scrapped 29 pages of apartment listings.
# You have 2040 listings left to go
#
#
# You have scrapped 30 pages of apartment listings.
# You have 2015 listings left to go
#
#
# You have scrapped 31 pages of apartment listings.
# You have 1992 listings left to go
#
#
# You have scrapped 32 pages of apartment listings.
# You have 1968 listings left to go
#
#
# You have scrapped 33 pages of apartment listings.
# You have 1944 listings left to go
#
#
# You have scrapped 34 pages of apartment listings.
# You have 1919 listings left to go
#
#
# You have scrapped 35 pages of apartment listings.
# You have 1896 listings left to go
#
#
# You have scrapped 36 pages of apartment listings.
# You have 1872 listings left to go
#
#
# You have scrapped 37 pages of apartment listings.
# You have 1847 listings left to go
#
#
# You have scrapped 38 pages of apartment listings.
# You have 1823 listings left to go
#
#
# You have scrapped 39 pages of apartment listings.
# You have 1800 listings left to go
#
#
# You have scrapped 40 pages of apartment listings.
# You have 1776 listings left to go
#
#
# You have scrapped 41 pages of apartment listings.
# You have 1752 listings left to go
#
#
# We are scraping the borough named: ['Ealing']
# You have scrapped 1 pages of apartment listings.
# You have 2341 listings left to go
#
#
# You have scrapped 2 pages of apartment listings.
# You have 2317 listings left to go
#
#
# You have scrapped 3 pages of apartment listings.
# You have 2293 listings left to go
#
#
# You have scrapped 4 pages of apartment listings.
# You have 2269 listings left to go
#
#
# You have scrapped 5 pages of apartment listings.
# You have 2245 listings left to go
#
#
# You have scrapped 6 pages of apartment listings.
# You have 2221 listings left to go
#
#
# You have scrapped 7 pages of apartment listings.
# You have 2197 listings left to go
#
#
# You have scrapped 8 pages of apartment listings.
# You have 2173 listings left to go
#
#
# You have scrapped 9 pages of apartment listings.
# You have 2149 listings left to go
#
#
# You have scrapped 10 pages of apartment listings.
# You have 2125 listings left to go
#
#
# You have scrapped 11 pages of apartment listings.
# You have 2101 listings left to go
#
#
# You have scrapped 12 pages of apartment listings.
# You have 2077 listings left to go
#
#
# You have scrapped 13 pages of apartment listings.
# You have 2053 listings left to go
#
#
# You have scrapped 14 pages of apartment listings.
# You have 2029 listings left to go
#
#
# You have scrapped 15 pages of apartment listings.
# You have 2005 listings left to go
#
#
# You have scrapped 16 pages of apartment listings.
# You have 1981 listings left to go
#
#
# You have scrapped 17 pages of apartment listings.
# You have 1957 listings left to go
#
#
# You have scrapped 18 pages of apartment listings.
# You have 1933 listings left to go
#
#
# You have scrapped 19 pages of apartment listings.
# You have 1909 listings left to go
#
#
# You have scrapped 20 pages of apartment listings.
# You have 1885 listings left to go
#
#
# You have scrapped 21 pages of apartment listings.
# You have 1861 listings left to go
#
#
# You have scrapped 22 pages of apartment listings.
# You have 1837 listings left to go
#
#
# You have scrapped 23 pages of apartment listings.
# You have 1813 listings left to go
#
#
# You have scrapped 24 pages of apartment listings.
# You have 1789 listings left to go
#
#
# You have scrapped 25 pages of apartment listings.
# You have 1765 listings left to go
#
#
# You have scrapped 26 pages of apartment listings.
# You have 1741 listings left to go
#
#
# You have scrapped 27 pages of apartment listings.
# You have 1717 listings left to go
#
#
# You have scrapped 28 pages of apartment listings.
# You have 1693 listings left to go
#
#
# You have scrapped 29 pages of apartment listings.
# You have 1669 listings left to go
#
#
# You have scrapped 30 pages of apartment listings.
# You have 1645 listings left to go
#
#
# You have scrapped 31 pages of apartment listings.
# You have 1621 listings left to go
#
#
# You have scrapped 32 pages of apartment listings.
# You have 1597 listings left to go
#
#
# You have scrapped 33 pages of apartment listings.
# You have 1573 listings left to go
#
#
# You have scrapped 34 pages of apartment listings.
# You have 1549 listings left to go
#
#
# You have scrapped 35 pages of apartment listings.
# You have 1525 listings left to go
#
#
# You have scrapped 36 pages of apartment listings.
# You have 1501 listings left to go
#
#
# You have scrapped 37 pages of apartment listings.
# You have 1477 listings left to go
#
#
# You have scrapped 38 pages of apartment listings.
# You have 1453 listings left to go
#
#
# You have scrapped 39 pages of apartment listings.
# You have 1429 listings left to go
#
#
# You have scrapped 40 pages of apartment listings.
# You have 1405 listings left to go
#
#
# You have scrapped 41 pages of apartment listings.
# You have 1381 listings left to go
#
#
# We are scraping the borough named: ['Enfield']
# You have scrapped 1 pages of apartment listings.
# You have 1354 listings left to go
#
#
# You have scrapped 2 pages of apartment listings.
# You have 1329 listings left to go
#
#
# You have scrapped 3 pages of apartment listings.
# You have 1306 listings left to go
#
#
# You have scrapped 4 pages of apartment listings.
# You have 1281 listings left to go
#
#
# You have scrapped 5 pages of apartment listings.
# You have 1257 listings left to go
#
#
# You have scrapped 6 pages of apartment listings.
# You have 1234 listings left to go
#
#
# You have scrapped 7 pages of apartment listings.
# You have 1210 listings left to go
#
#
# You have scrapped 8 pages of apartment listings.
# You have 1185 listings left to go
#
#
# You have scrapped 9 pages of apartment listings.
# You have 1161 listings left to go
#
#
# You have scrapped 10 pages of apartment listings.
# You have 1138 listings left to go
#
#
# You have scrapped 11 pages of apartment listings.
# You have 1114 listings left to go
#
#
# You have scrapped 12 pages of apartment listings.
# You have 1090 listings left to go
#
#
# You have scrapped 13 pages of apartment listings.
# You have 1066 listings left to go
#
#
# You have scrapped 14 pages of apartment listings.
# You have 1041 listings left to go
#
#
# You have scrapped 15 pages of apartment listings.
# You have 1017 listings left to go
#
#
# You have scrapped 16 pages of apartment listings.
# You have 994 listings left to go
#
#
# You have scrapped 17 pages of apartment listings.
# You have 970 listings left to go
#
#
# You have scrapped 18 pages of apartment listings.
# You have 946 listings left to go
#
#
# You have scrapped 19 pages of apartment listings.
# You have 922 listings left to go
#
#
# You have scrapped 20 pages of apartment listings.
# You have 898 listings left to go
#
#
# You have scrapped 21 pages of apartment listings.
# You have 874 listings left to go
#
#
# You have scrapped 22 pages of apartment listings.
# You have 850 listings left to go
#
#
# You have scrapped 23 pages of apartment listings.
# You have 826 listings left to go
#
#
# You have scrapped 24 pages of apartment listings.
# You have 801 listings left to go
#
#
# You have scrapped 25 pages of apartment listings.
# You have 777 listings left to go
#
#
# You have scrapped 26 pages of apartment listings.
# You have 754 listings left to go
#
#
# You have scrapped 27 pages of apartment listings.
# You have 730 listings left to go
#
#
# You have scrapped 28 pages of apartment listings.
# You have 706 listings left to go
#
#
# You have scrapped 29 pages of apartment listings.
# You have 681 listings left to go
#
#
# You have scrapped 30 pages of apartment listings.
# You have 658 listings left to go
#
#
# You have scrapped 31 pages of apartment listings.
# You have 634 listings left to go
#
#
# You have scrapped 32 pages of apartment listings.
# You have 610 listings left to go
#
#
# You have scrapped 33 pages of apartment listings.
# You have 586 listings left to go
#
#
# You have scrapped 34 pages of apartment listings.
# You have 561 listings left to go
#
#
# You have scrapped 35 pages of apartment listings.
# You have 537 listings left to go
#
#
# You have scrapped 36 pages of apartment listings.
# You have 514 listings left to go
#
#
# You have scrapped 37 pages of apartment listings.
# You have 490 listings left to go
#
#
# You have scrapped 38 pages of apartment listings.
# You have 465 listings left to go
#
#
# You have scrapped 39 pages of apartment listings.
# You have 441 listings left to go
#
#
# You have scrapped 40 pages of apartment listings.
# You have 417 listings left to go
#
#
# You have scrapped 41 pages of apartment listings.
# You have 394 listings left to go
#
#
# We are scraping the borough named: ['Greenwich']
# You have scrapped 1 pages of apartment listings.
# You have 1562 listings left to go
#
#
# You have scrapped 2 pages of apartment listings.
# You have 1538 listings left to go
#
#
# You have scrapped 3 pages of apartment listings.
# You have 1515 listings left to go
#
#
# You have scrapped 4 pages of apartment listings.
# You have 1491 listings left to go
#
#
# You have scrapped 5 pages of apartment listings.
# You have 1467 listings left to go
#
#
# You have scrapped 6 pages of apartment listings.
# You have 1442 listings left to go
#
#
# You have scrapped 7 pages of apartment listings.
# You have 1419 listings left to go
#
#
# You have scrapped 8 pages of apartment listings.
# You have 1395 listings left to go
#
#
# You have scrapped 9 pages of apartment listings.
# You have 1370 listings left to go
#
#
# You have scrapped 10 pages of apartment listings.
# You have 1347 listings left to go
#
#
# You have scrapped 11 pages of apartment listings.
# You have 1323 listings left to go
#
#
# You have scrapped 12 pages of apartment listings.
# You have 1298 listings left to go
#
#
# You have scrapped 13 pages of apartment listings.
# You have 1275 listings left to go
#
#
# You have scrapped 14 pages of apartment listings.
# You have 1250 listings left to go
#
#
# You have scrapped 15 pages of apartment listings.
# You have 1227 listings left to go
#
#
# You have scrapped 16 pages of apartment listings.
# You have 1202 listings left to go
#
#
# You have scrapped 17 pages of apartment listings.
# You have 1178 listings left to go
#
#
# You have scrapped 18 pages of apartment listings.
# You have 1155 listings left to go
#
#
# You have scrapped 19 pages of apartment listings.
# You have 1131 listings left to go
#
#
# You have scrapped 20 pages of apartment listings.
# You have 1107 listings left to go
#
#
# You have scrapped 21 pages of apartment listings.
# You have 1082 listings left to go
#
#
# You have scrapped 22 pages of apartment listings.
# You have 1059 listings left to go
#
#
# You have scrapped 23 pages of apartment listings.
# You have 1035 listings left to go
#
#
# You have scrapped 24 pages of apartment listings.
# You have 1010 listings left to go
#
#
# You have scrapped 25 pages of apartment listings.
# You have 987 listings left to go
#
#
# You have scrapped 26 pages of apartment listings.
# You have 963 listings left to go
#
#
# You have scrapped 27 pages of apartment listings.
# You have 939 listings left to go
#
#
# You have scrapped 28 pages of apartment listings.
# You have 915 listings left to go
#
#
# You have scrapped 29 pages of apartment listings.
# You have 891 listings left to go
#
#
# You have scrapped 30 pages of apartment listings.
# You have 867 listings left to go
#
#
# You have scrapped 31 pages of apartment listings.
# You have 842 listings left to go
#
#
# You have scrapped 32 pages of apartment listings.
# You have 818 listings left to go
#
#
# You have scrapped 33 pages of apartment listings.
# You have 794 listings left to go
#
#
# You have scrapped 34 pages of apartment listings.
# You have 771 listings left to go
#
#
# You have scrapped 35 pages of apartment listings.
# You have 747 listings left to go
#
#
# You have scrapped 36 pages of apartment listings.
# You have 722 listings left to go
#
#
# You have scrapped 37 pages of apartment listings.
# You have 699 listings left to go
#
#
# You have scrapped 38 pages of apartment listings.
# You have 675 listings left to go
#
#
# You have scrapped 39 pages of apartment listings.
# You have 650 listings left to go
#
#
# You have scrapped 40 pages of apartment listings.
# You have 626 listings left to go
#
#
# You have scrapped 41 pages of apartment listings.
# You have 602 listings left to go
#
#
# We are scraping the borough named: ['Hackney']
# You have scrapped 1 pages of apartment listings.
# You have 1410 listings left to go
#
#
# You have scrapped 2 pages of apartment listings.
# You have 1385 listings left to go
#
#
# You have scrapped 3 pages of apartment listings.
# You have 1362 listings left to go
#
#
# You have scrapped 4 pages of apartment listings.
# You have 1338 listings left to go
#
#
# You have scrapped 5 pages of apartment listings.
# You have 1313 listings left to go
#
#
# You have scrapped 6 pages of apartment listings.
# You have 1290 listings left to go
#
#
# You have scrapped 7 pages of apartment listings.
# You have 1265 listings left to go
#
#
# You have scrapped 8 pages of apartment listings.
# You have 1241 listings left to go
#
#
# You have scrapped 9 pages of apartment listings.
# You have 1218 listings left to go
#
#
# You have scrapped 10 pages of apartment listings.
# You have 1193 listings left to go
#
#
# You have scrapped 11 pages of apartment listings.
# You have 1169 listings left to go
#
#
# You have scrapped 12 pages of apartment listings.
# You have 1145 listings left to go
#
#
# You have scrapped 13 pages of apartment listings.
# You have 1122 listings left to go
#
#
# You have scrapped 14 pages of apartment listings.
# You have 1097 listings left to go
#
#
# You have scrapped 15 pages of apartment listings.
# You have 1073 listings left to go
#
#
# You have scrapped 16 pages of apartment listings.
# You have 1050 listings left to go
#
#
# You have scrapped 17 pages of apartment listings.
# You have 1026 listings left to go
#
#
# You have scrapped 18 pages of apartment listings.
# You have 1001 listings left to go
#
#
# You have scrapped 19 pages of apartment listings.
# You have 977 listings left to go
#
#
# You have scrapped 20 pages of apartment listings.
# You have 953 listings left to go
#
#
# You have scrapped 21 pages of apartment listings.
# You have 930 listings left to go
#
#
# You have scrapped 22 pages of apartment listings.
# You have 905 listings left to go
#
#
# You have scrapped 23 pages of apartment listings.
# You have 882 listings left to go
#
#
# You have scrapped 24 pages of apartment listings.
# You have 857 listings left to go
#
#
# You have scrapped 25 pages of apartment listings.
# You have 833 listings left to go
#
#
# You have scrapped 26 pages of apartment listings.
# You have 809 listings left to go
#
#
# You have scrapped 27 pages of apartment listings.
# You have 785 listings left to go
#
#
# You have scrapped 28 pages of apartment listings.
# You have 761 listings left to go
#
#
# You have scrapped 29 pages of apartment listings.
# You have 737 listings left to go
#
#
# You have scrapped 30 pages of apartment listings.
# You have 714 listings left to go
#
#
# You have scrapped 31 pages of apartment listings.
# You have 690 listings left to go
#
#
# You have scrapped 32 pages of apartment listings.
# You have 665 listings left to go
#
#
# You have scrapped 33 pages of apartment listings.
# You have 641 listings left to go
#
#
# You have scrapped 34 pages of apartment listings.
# You have 617 listings left to go
#
#
# You have scrapped 35 pages of apartment listings.
# You have 594 listings left to go
#
#
# You have scrapped 36 pages of apartment listings.
# You have 569 listings left to go
#
#
# You have scrapped 37 pages of apartment listings.
# You have 546 listings left to go
#
#
# You have scrapped 38 pages of apartment listings.
# You have 521 listings left to go
#
#
# You have scrapped 39 pages of apartment listings.
# You have 497 listings left to go
#
#
# You have scrapped 40 pages of apartment listings.
# You have 474 listings left to go
#
#
# You have scrapped 41 pages of apartment listings.
# You have 449 listings left to go
#
#
# We are scraping the borough named: ['Hammersmith and Fulham']
# You have scrapped 1 pages of apartment listings.
# You have 2145 listings left to go
#
#
# You have scrapped 2 pages of apartment listings.
# You have 2121 listings left to go
#
#
# You have scrapped 3 pages of apartment listings.
# You have 2099 listings left to go
#
#
# You have scrapped 4 pages of apartment listings.
# You have 2075 listings left to go
#
#
# You have scrapped 5 pages of apartment listings.
# You have 2051 listings left to go
#
#
# You have scrapped 6 pages of apartment listings.
# You have 2025 listings left to go
#
#
# You have scrapped 7 pages of apartment listings.
# You have 2001 listings left to go
#
#
# You have scrapped 8 pages of apartment listings.
# You have 1977 listings left to go
#
#
# You have scrapped 9 pages of apartment listings.
# You have 1953 listings left to go
#
#
# You have scrapped 10 pages of apartment listings.
# You have 1929 listings left to go
#
#
# You have scrapped 11 pages of apartment listings.
# You have 1905 listings left to go
#
#
# You have scrapped 12 pages of apartment listings.
# You have 1881 listings left to go
#
#
# You have scrapped 13 pages of apartment listings.
# You have 1859 listings left to go
#
#
# You have scrapped 14 pages of apartment listings.
# You have 1833 listings left to go
#
#
# You have scrapped 15 pages of apartment listings.
# You have 1811 listings left to go
#
#
# You have scrapped 16 pages of apartment listings.
# You have 1787 listings left to go
#
#
# You have scrapped 17 pages of apartment listings.
# You have 1761 listings left to go
#
#
# You have scrapped 18 pages of apartment listings.
# You have 1739 listings left to go
#
#
# You have scrapped 19 pages of apartment listings.
# You have 1713 listings left to go
#
#
# You have scrapped 20 pages of apartment listings.
# You have 1691 listings left to go
#
#
# You have scrapped 21 pages of apartment listings.
# You have 1665 listings left to go
#
#
# You have scrapped 22 pages of apartment listings.
# You have 1641 listings left to go
#
#
# You have scrapped 23 pages of apartment listings.
# You have 1617 listings left to go
#
#
# You have scrapped 24 pages of apartment listings.
# You have 1593 listings left to go
#
#
# You have scrapped 25 pages of apartment listings.
# You have 1569 listings left to go
#
#
# You have scrapped 26 pages of apartment listings.
# You have 1545 listings left to go
#
#
# You have scrapped 27 pages of apartment listings.
# You have 1521 listings left to go
#
#
# You have scrapped 28 pages of apartment listings.
# You have 1499 listings left to go
#
#
# You have scrapped 29 pages of apartment listings.
# You have 1475 listings left to go
#
#
# You have scrapped 30 pages of apartment listings.
# You have 1449 listings left to go
#
#
# You have scrapped 31 pages of apartment listings.
# You have 1425 listings left to go
#
#
# You have scrapped 32 pages of apartment listings.
# You have 1403 listings left to go
#
#
# You have scrapped 33 pages of apartment listings.
# You have 1377 listings left to go
#
#
# You have scrapped 34 pages of apartment listings.
# You have 1353 listings left to go
#
#
# You have scrapped 35 pages of apartment listings.
# You have 1331 listings left to go
#
#
# You have scrapped 36 pages of apartment listings.
# You have 1307 listings left to go
#
#
# You have scrapped 37 pages of apartment listings.
# You have 1281 listings left to go
#
#
# You have scrapped 38 pages of apartment listings.
# You have 1257 listings left to go
#
#
# You have scrapped 39 pages of apartment listings.
# You have 1233 listings left to go
#
#
# You have scrapped 40 pages of apartment listings.
# You have 1209 listings left to go
#
#
# You have scrapped 41 pages of apartment listings.
# You have 1187 listings left to go
#
#
# We are scraping the borough named: ['Haringey']
# You have scrapped 1 pages of apartment listings.
# You have 1218 listings left to go
#
#
# You have scrapped 2 pages of apartment listings.
# You have 1194 listings left to go
#
#
# You have scrapped 3 pages of apartment listings.
# You have 1167 listings left to go
#
#
# You have scrapped 4 pages of apartment listings.
# You have 1143 listings left to go
#
#
# You have scrapped 5 pages of apartment listings.
# You have 1122 listings left to go
#
#
# You have scrapped 6 pages of apartment listings.
# You have 1095 listings left to go
#
#
# You have scrapped 7 pages of apartment listings.
# You have 1071 listings left to go
#
#
# You have scrapped 8 pages of apartment listings.
# You have 1047 listings left to go
#
#
# You have scrapped 9 pages of apartment listings.
# You have 1023 listings left to go
#
#
# You have scrapped 10 pages of apartment listings.
# You have 999 listings left to go
#
#
# You have scrapped 11 pages of apartment listings.
# You have 975 listings left to go
#
#
# You have scrapped 12 pages of apartment listings.
# You have 954 listings left to go
#
#
# You have scrapped 13 pages of apartment listings.
# You have 930 listings left to go
#
#
# You have scrapped 14 pages of apartment listings.
# You have 903 listings left to go
#
#
# You have scrapped 15 pages of apartment listings.
# You have 882 listings left to go
#
#
# You have scrapped 16 pages of apartment listings.
# You have 858 listings left to go
#
#
# You have scrapped 17 pages of apartment listings.
# You have 834 listings left to go
#
#
# You have scrapped 18 pages of apartment listings.
# You have 807 listings left to go
#
#
# You have scrapped 19 pages of apartment listings.
# You have 783 listings left to go
#
#
# You have scrapped 20 pages of apartment listings.
# You have 759 listings left to go
#
#
# You have scrapped 21 pages of apartment listings.
# You have 735 listings left to go
#
#
# You have scrapped 22 pages of apartment listings.
# You have 714 listings left to go
#
#
# You have scrapped 23 pages of apartment listings.
# You have 687 listings left to go
#
#
# You have scrapped 24 pages of apartment listings.
# You have 663 listings left to go
#
#
# You have scrapped 25 pages of apartment listings.
# You have 639 listings left to go
#
#
# You have scrapped 26 pages of apartment listings.
# You have 615 listings left to go
#
#
# You have scrapped 27 pages of apartment listings.
# You have 591 listings left to go
#
#
# You have scrapped 28 pages of apartment listings.
# You have 567 listings left to go
#
#
# You have scrapped 29 pages of apartment listings.
# You have 543 listings left to go
#
#
# You have scrapped 30 pages of apartment listings.
# You have 519 listings left to go
#
#
# You have scrapped 31 pages of apartment listings.
# You have 495 listings left to go
#
#
# You have scrapped 32 pages of apartment listings.
# You have 474 listings left to go
#
#
# You have scrapped 33 pages of apartment listings.
# You have 447 listings left to go
#
#
# You have scrapped 34 pages of apartment listings.
# You have 423 listings left to go
#
#
# You have scrapped 35 pages of apartment listings.
# You have 402 listings left to go
#
#
# You have scrapped 36 pages of apartment listings.
# You have 378 listings left to go
#
#
# You have scrapped 37 pages of apartment listings.
# You have 354 listings left to go
#
#
# You have scrapped 38 pages of apartment listings.
# You have 327 listings left to go
#
#
# You have scrapped 39 pages of apartment listings.
# You have 303 listings left to go
#
#
# You have scrapped 40 pages of apartment listings.
# You have 282 listings left to go
#
#
# You have scrapped 41 pages of apartment listings.
# You have 255 listings left to go
#
#
# We are scraping the borough named: ['Harrow']
# You have scrapped 1 pages of apartment listings.
# You have 1352 listings left to go
#
#
# You have scrapped 2 pages of apartment listings.
# You have 1328 listings left to go
#
#
# You have scrapped 3 pages of apartment listings.
# You have 1304 listings left to go
#
#
# You have scrapped 4 pages of apartment listings.
# You have 1280 listings left to go
#
#
# You have scrapped 5 pages of apartment listings.
# You have 1256 listings left to go
#
#
# You have scrapped 6 pages of apartment listings.
# You have 1232 listings left to go
#
#
# You have scrapped 7 pages of apartment listings.
# You have 1208 listings left to go
#
#
# You have scrapped 8 pages of apartment listings.
# You have 1184 listings left to go
#
#
# You have scrapped 9 pages of apartment listings.
# You have 1160 listings left to go
#
#
# You have scrapped 10 pages of apartment listings.
# You have 1136 listings left to go
#
#
# You have scrapped 11 pages of apartment listings.
# You have 1112 listings left to go
#
#
# You have scrapped 12 pages of apartment listings.
# You have 1088 listings left to go
#
#
# You have scrapped 13 pages of apartment listings.
# You have 1064 listings left to go
#
#
# You have scrapped 14 pages of apartment listings.
# You have 1040 listings left to go
#
#
# You have scrapped 15 pages of apartment listings.
# You have 1016 listings left to go
#
#
# You have scrapped 16 pages of apartment listings.
# You have 991 listings left to go
#
#
# You have scrapped 17 pages of apartment listings.
# You have 967 listings left to go
#
#
# You have scrapped 18 pages of apartment listings.
# You have 943 listings left to go
#
#
# You have scrapped 19 pages of apartment listings.
# You have 919 listings left to go
#
#
# You have scrapped 20 pages of apartment listings.
# You have 895 listings left to go
#
#
# You have scrapped 21 pages of apartment listings.
# You have 871 listings left to go
#
#
# You have scrapped 22 pages of apartment listings.
# You have 847 listings left to go
#
#
# You have scrapped 23 pages of apartment listings.
# You have 823 listings left to go
#
#
# You have scrapped 24 pages of apartment listings.
# You have 799 listings left to go
#
#
# You have scrapped 25 pages of apartment listings.
# You have 775 listings left to go
#
#
# You have scrapped 26 pages of apartment listings.
# You have 751 listings left to go
#
#
# You have scrapped 27 pages of apartment listings.
# You have 727 listings left to go
#
#
# You have scrapped 28 pages of apartment listings.
# You have 703 listings left to go
#
#
# You have scrapped 29 pages of apartment listings.
# You have 679 listings left to go
#
#
# You have scrapped 30 pages of apartment listings.
# You have 655 listings left to go
#
#
# You have scrapped 31 pages of apartment listings.
# You have 631 listings left to go
#
#
# You have scrapped 32 pages of apartment listings.
# You have 607 listings left to go
#
#
# You have scrapped 33 pages of apartment listings.
# You have 583 listings left to go
#
#
# You have scrapped 34 pages of apartment listings.
# You have 559 listings left to go
#
#
# You have scrapped 35 pages of apartment listings.
# You have 535 listings left to go
#
#
# You have scrapped 36 pages of apartment listings.
# You have 511 listings left to go
#
#
# You have scrapped 37 pages of apartment listings.
# You have 487 listings left to go
#
#
# You have scrapped 38 pages of apartment listings.
# You have 463 listings left to go
#
#
# You have scrapped 39 pages of apartment listings.
# You have 439 listings left to go
#
#
# You have scrapped 40 pages of apartment listings.
# You have 415 listings left to go
#
#
# You have scrapped 41 pages of apartment listings.
# You have 391 listings left to go
#
#
# We are scraping the borough named: ['Havering']
# You have scrapped 1 pages of apartment listings.
# You have 1238 listings left to go
#
#
# You have scrapped 2 pages of apartment listings.
# You have 1214 listings left to go
#
#
# You have scrapped 3 pages of apartment listings.
# You have 1190 listings left to go
#
#
# You have scrapped 4 pages of apartment listings.
# You have 1166 listings left to go
#
#
# You have scrapped 5 pages of apartment listings.
# You have 1142 listings left to go
#
#
# You have scrapped 6 pages of apartment listings.
# You have 1118 listings left to go
#
#
# You have scrapped 7 pages of apartment listings.
# You have 1094 listings left to go
#
#
# You have scrapped 8 pages of apartment listings.
# You have 1070 listings left to go
#
#
# You have scrapped 9 pages of apartment listings.
# You have 1046 listings left to go
#
#
# You have scrapped 10 pages of apartment listings.
# You have 1022 listings left to go
#
#
# You have scrapped 11 pages of apartment listings.
# You have 998 listings left to go
#
#
# You have scrapped 12 pages of apartment listings.
# You have 974 listings left to go
#
#
# You have scrapped 13 pages of apartment listings.
# You have 950 listings left to go
#
#
# You have scrapped 14 pages of apartment listings.
# You have 926 listings left to go
#
#
# You have scrapped 15 pages of apartment listings.
# You have 902 listings left to go
#
#
# You have scrapped 16 pages of apartment listings.
# You have 878 listings left to go
#
#
# You have scrapped 17 pages of apartment listings.
# You have 854 listings left to go
#
#
# You have scrapped 18 pages of apartment listings.
# You have 830 listings left to go
#
#
# You have scrapped 19 pages of apartment listings.
# You have 806 listings left to go
#
#
# You have scrapped 20 pages of apartment listings.
# You have 782 listings left to go
#
#
# You have scrapped 21 pages of apartment listings.
# You have 758 listings left to go
#
#
# You have scrapped 22 pages of apartment listings.
# You have 734 listings left to go
#
#
# You have scrapped 23 pages of apartment listings.
# You have 710 listings left to go
#
#
# You have scrapped 24 pages of apartment listings.
# You have 686 listings left to go
#
#
# You have scrapped 25 pages of apartment listings.
# You have 662 listings left to go
#
#
# You have scrapped 26 pages of apartment listings.
# You have 638 listings left to go
#
#
# You have scrapped 27 pages of apartment listings.
# You have 614 listings left to go
#
#
# You have scrapped 28 pages of apartment listings.
# You have 590 listings left to go
#
#
# You have scrapped 29 pages of apartment listings.
# You have 566 listings left to go
#
#
# You have scrapped 30 pages of apartment listings.
# You have 542 listings left to go
#
#
# You have scrapped 31 pages of apartment listings.
# You have 518 listings left to go
#
#
# You have scrapped 32 pages of apartment listings.
# You have 494 listings left to go
#
#
# You have scrapped 33 pages of apartment listings.
# You have 470 listings left to go
#
#
# You have scrapped 34 pages of apartment listings.
# You have 446 listings left to go
#
#
# You have scrapped 35 pages of apartment listings.
# You have 422 listings left to go
#
#
# You have scrapped 36 pages of apartment listings.
# You have 398 listings left to go
#
#
# You have scrapped 37 pages of apartment listings.
# You have 374 listings left to go
#
#
# You have scrapped 38 pages of apartment listings.
# You have 350 listings left to go
#
#
# You have scrapped 39 pages of apartment listings.
# You have 326 listings left to go
#
#
# You have scrapped 40 pages of apartment listings.
# You have 302 listings left to go
#
#
# You have scrapped 41 pages of apartment listings.
# You have 278 listings left to go
#
#
# We are scraping the borough named: ['Hillingdon']
# You have scrapped 1 pages of apartment listings.
# You have 1485 listings left to go
#
#
# You have scrapped 2 pages of apartment listings.
# You have 1461 listings left to go
#
#
# You have scrapped 3 pages of apartment listings.
# You have 1437 listings left to go
#
#
# You have scrapped 4 pages of apartment listings.
# You have 1413 listings left to go
#
#
# You have scrapped 5 pages of apartment listings.
# You have 1389 listings left to go
#
#
# You have scrapped 6 pages of apartment listings.
# You have 1365 listings left to go
#
#
# You have scrapped 7 pages of apartment listings.
# You have 1341 listings left to go
#
#
# You have scrapped 8 pages of apartment listings.
# You have 1317 listings left to go
#
#
# ...
# You have 517 listings left to go
#
#
# You have scrapped 22 pages of apartment listings.
# You have 494 listings left to go
#
#
# You have scrapped 23 pages of apartment listings.
# You have 470 listings left to go
#
#
# You have scrapped 24 pages of apartment listings.
# You have 446 listings left to go
#
#
# You have scrapped 25 pages of apartment listings.
# You have 422 listings left to go
#
#
# You have scrapped 26 pages of apartment listings.
# You have 397 listings left to go
#
#
# You have scrapped 27 pages of apartment listings.
# You have 373 listings left to go
#
#
# You have scrapped 28 pages of apartment listings.
# You have 350 listings left to go
#
#
# You have scrapped 29 pages of apartment listings.
# You have 326 listings left to go
#
#
# You have scrapped 30 pages of apartment listings.
# You have 301 listings left to go
#
#
# You have scrapped 31 pages of apartment listings.
# You have 277 listings left to go
#
#
# You have scrapped 32 pages of apartment listings.
# You have 253 listings left to go
#
#
# You have scrapped 33 pages of apartment listings.
# You have 229 listings left to go
#
#
# You have scrapped 34 pages of apartment listings.
# You have 205 listings left to go
#
#
# You have scrapped 35 pages of apartment listings.
# You have 181 listings left to go
#
#
# You have scrapped 36 pages of apartment listings.
# You have 157 listings left to go
#
#
# You have scrapped 37 pages of apartment listings.
# You have 133 listings left to go
#
#
# You have scrapped 38 pages of apartment listings.
# You have 110 listings left to go
#
#
# You have scrapped 39 pages of apartment listings.
# You have 85 listings left to go
#
#
# You have scrapped 40 pages of apartment listings.
# You have 62 listings left to go
#
#
# You have scrapped 41 pages of apartment listings.
# You have 37 listings left to go
#
#
# We are scraping the borough named: ['Tower Hamlets']
# You have scrapped 1 pages of apartment listings.
# You have 2606 listings left to go
#
#
# You have scrapped 2 pages of apartment listings.
# You have 2586 listings left to go
#
#
# You have scrapped 3 pages of apartment listings.
# You have 2562 listings left to go
#
#
# You have scrapped 4 pages of apartment listings.
# You have 2534 listings left to go
#
#
# You have scrapped 5 pages of apartment listings.
# You have 2514 listings left to go
#
#
# You have scrapped 6 pages of apartment listings.
# You have 2488 listings left to go
#
#
# You have scrapped 7 pages of apartment listings.
# You have 2462 listings left to go
#
#
# You have scrapped 8 pages of apartment listings.
# You have 2438 listings left to go
#
#
# You have scrapped 9 pages of apartment listings.
# You have 2416 listings left to go
#
#
# You have scrapped 10 pages of apartment listings.
# You have 2394 listings left to go
#
#
# You have scrapped 11 pages of apartment listings.
# You have 2368 listings left to go
#
#
# You have scrapped 12 pages of apartment listings.
# You have 2342 listings left to go
#
#
# You have scrapped 13 pages of apartment listings.
# You have 2318 listings left to go
#
#
# You have scrapped 14 pages of apartment listings.
# You have 2296 listings left to go
#
#
# You have scrapped 15 pages of apartment listings.
# You have 2272 listings left to go
#
#
# You have scrapped 16 pages of apartment listings.
# You have 2246 listings left to go
#
#
# You have scrapped 17 pages of apartment listings.
# You have 2224 listings left to go
#
#
# You have scrapped 18 pages of apartment listings.
# You have 2200 listings left to go
#
#
# You have scrapped 19 pages of apartment listings.
# You have 2176 listings left to go
#
#
# You have scrapped 20 pages of apartment listings.
# You have 2150 listings left to go
#
#
# You have scrapped 21 pages of apartment listings.
# You have 2130 listings left to go
#
#
# You have scrapped 22 pages of apartment listings.
# You have 2104 listings left to go
#
#
# You have scrapped 23 pages of apartment listings.
# You have 2078 listings left to go
#
#
# You have scrapped 24 pages of apartment listings.
# You have 2056 listings left to go
#
#
# You have scrapped 25 pages of apartment listings.
# You have 2034 listings left to go
#
#
# You have scrapped 26 pages of apartment listings.
# You have 2010 listings left to go
#
#
# You have scrapped 27 pages of apartment listings.
# You have 1984 listings left to go
#
#
# You have scrapped 28 pages of apartment listings.
# You have 1960 listings left to go
#
#
# You have scrapped 29 pages of apartment listings.
# You have 1936 listings left to go
#
#
# You have scrapped 30 pages of apartment listings.
# You have 1910 listings left to go
#
#
# You have scrapped 31 pages of apartment listings.
# You have 1886 listings left to go
#
#
# You have scrapped 32 pages of apartment listings.
# You have 1864 listings left to go
#
#
# You have scrapped 33 pages of apartment listings.
# You have 1842 listings left to go
#
#
# You have scrapped 34 pages of apartment listings.
# You have 1816 listings left to go
#
#
# You have scrapped 35 pages of apartment listings.
# You have 1790 listings left to go
#
#
# You have scrapped 36 pages of apartment listings.
# You have 1768 listings left to go
#
#
# You have scrapped 37 pages of apartment listings.
# You have 1746 listings left to go
#
#
# You have scrapped 38 pages of apartment listings.
# You have 1720 listings left to go
#
#
# You have scrapped 39 pages of apartment listings.
# You have 1698 listings left to go
#
#
# You have scrapped 40 pages of apartment listings.
# You have 1672 listings left to go
#
#
# You have scrapped 41 pages of apartment listings.
# You have 1648 listings left to go
#
#
# We are scraping the borough named: ['Waltham Forest']
# You have scrapped 1 pages of apartment listings.
# You have 1102 listings left to go
#
#
# You have scrapped 2 pages of apartment listings.
# You have 1080 listings left to go
#
#
# You have scrapped 3 pages of apartment listings.
# You have 1054 listings left to go
#
#
# You have scrapped 4 pages of apartment listings.
# You have 1032 listings left to go
#
#
# You have scrapped 5 pages of apartment listings.
# You have 1008 listings left to go
#
#
# You have scrapped 6 pages of apartment listings.
# You have 982 listings left to go
#
#
# You have scrapped 7 pages of apartment listings.
# You have 958 listings left to go
#
#
# You have scrapped 8 pages of apartment listings.
# You have 935 listings left to go
#
#
# You have scrapped 9 pages of apartment listings.
# You have 910 listings left to go
#
#
# You have scrapped 10 pages of apartment listings.
# You have 886 listings left to go
#
#
# You have scrapped 11 pages of apartment listings.
# You have 863 listings left to go
#
#
# You have scrapped 12 pages of apartment listings.
# You have 839 listings left to go
#
#
# You have scrapped 13 pages of apartment listings.
# You have 814 listings left to go
#
#
# You have scrapped 14 pages of apartment listings.
# You have 791 listings left to go
#
#
# You have scrapped 15 pages of apartment listings.
# You have 767 listings left to go
#
#
# You have scrapped 16 pages of apartment listings.
# You have 743 listings left to go
#
#
# You have scrapped 17 pages of apartment listings.
# You have 720 listings left to go
#
#
# You have scrapped 18 pages of apartment listings.
# You have 694 listings left to go
#
#
# You have scrapped 19 pages of apartment listings.
# You have 671 listings left to go
#
#
# You have scrapped 20 pages of apartment listings.
# You have 648 listings left to go
#
#
# You have scrapped 21 pages of apartment listings.
# You have 622 listings left to go
#
#
# You have scrapped 22 pages of apartment listings.
# You have 598 listings left to go
#
#
# You have scrapped 23 pages of apartment listings.
# You have 575 listings left to go
#
#
# You have scrapped 24 pages of apartment listings.
# You have 550 listings left to go
#
#
# You have scrapped 25 pages of apartment listings.
# You have 526 listings left to go
#
#
# You have scrapped 26 pages of apartment listings.
# You have 502 listings left to go
#
#
# You have scrapped 27 pages of apartment listings.
# You have 479 listings left to go
#
#
# You have scrapped 28 pages of apartment listings.
# You have 455 listings left to go
#
#
# You have scrapped 29 pages of apartment listings.
# You have 432 listings left to go
#
#
# You have scrapped 30 pages of apartment listings.
# You have 408 listings left to go
#
#
# You have scrapped 31 pages of apartment listings.
# You have 384 listings left to go
#
#
# You have scrapped 32 pages of apartment listings.
# You have 360 listings left to go
#
#
# You have scrapped 33 pages of apartment listings.
# You have 335 listings left to go
#
#
# You have scrapped 34 pages of apartment listings.
# You have 310 listings left to go
#
#
# You have scrapped 35 pages of apartment listings.
# You have 287 listings left to go
#
#
# You have scrapped 36 pages of apartment listings.
# You have 262 listings left to go
#
#
# You have scrapped 37 pages of apartment listings.
# You have 240 listings left to go
#
#
# You have scrapped 38 pages of apartment listings.
# You have 215 listings left to go
#
#
# You have scrapped 39 pages of apartment listings.
# You have 192 listings left to go
#
#
# You have scrapped 40 pages of apartment listings.
# You have 167 listings left to go
#
#
# You have scrapped 41 pages of apartment listings.
# You have 143 listings left to go
#
#
# We are scraping the borough named: ['Wandsworth']
# You have scrapped 1 pages of apartment listings.
# You have 3237 listings left to go
#
#
# You have scrapped 2 pages of apartment listings.
# You have 3202 listings left to go
#
#
# You have scrapped 3 pages of apartment listings.
# You have 3189 listings left to go
#
#
# You have scrapped 4 pages of apartment listings.
# You have 3153 listings left to go
#
#
# You have scrapped 5 pages of apartment listings.
# You have 3130 listings left to go
#
#
# You have scrapped 6 pages of apartment listings.
# You have 3105 listings left to go
#
#
# You have scrapped 7 pages of apartment listings.
# You have 3082 listings left to go
#
#
# You have scrapped 8 pages of apartment listings.
# You have 3057 listings left to go
#
#
# You have scrapped 9 pages of apartment listings.
# You have 3033 listings left to go
#
#
# You have scrapped 10 pages of apartment listings.
# You have 3010 listings left to go
#
#
# You have scrapped 11 pages of apartment listings.
# You have 2997 listings left to go
#
#
# You have scrapped 12 pages of apartment listings.
# You have 2973 listings left to go
#
#
# You have scrapped 13 pages of apartment listings.
# You have 2938 listings left to go
#
#
# You have scrapped 14 pages of apartment listings.
# You have 2913 listings left to go
#
#
# You have scrapped 15 pages of apartment listings.
# You have 2901 listings left to go
#
#
# You have scrapped 16 pages of apartment listings.
# You have 2877 listings left to go
#
#
# You have scrapped 17 pages of apartment listings.
# You have 2841 listings left to go
#
#
# You have scrapped 18 pages of apartment listings.
# You have 2818 listings left to go
#
#
# You have scrapped 19 pages of apartment listings.
# You have 2793 listings left to go
#
#
# You have scrapped 20 pages of apartment listings.
# You have 2781 listings left to go
#
#
# You have scrapped 21 pages of apartment listings.
# You have 2746 listings left to go
#
#
# You have scrapped 22 pages of apartment listings.
# You have 2722 listings left to go
#
#
# You have scrapped 23 pages of apartment listings.
# You have 2698 listings left to go
#
#
# You have scrapped 24 pages of apartment listings.
# You have 2685 listings left to go
#
#
# You have scrapped 25 pages of apartment listings.
# You have 2649 listings left to go
#
#
# You have scrapped 26 pages of apartment listings.
# You have 2626 listings left to go
#
#
# You have scrapped 27 pages of apartment listings.
# You have 2601 listings left to go
#
#
# You have scrapped 28 pages of apartment listings.
# You have 2589 listings left to go
#
#
# You have scrapped 29 pages of apartment listings.
# You have 2553 listings left to go
#
#
# You have scrapped 30 pages of apartment listings.
# You have 2541 listings left to go
#
#
# You have scrapped 31 pages of apartment listings.
# You have 2517 listings left to go
#
#
# You have scrapped 32 pages of apartment listings.
# You have 2482 listings left to go
#
#
# You have scrapped 33 pages of apartment listings.
# You have 2469 listings left to go
#
#
# You have scrapped 34 pages of apartment listings.
# You have 2433 listings left to go
#
#
# You have scrapped 35 pages of apartment listings.
# You have 2410 listings left to go
#
#
# You have scrapped 36 pages of apartment listings.
# You have 2385 listings left to go
#
#
# You have scrapped 37 pages of apartment listings.
# You have 2373 listings left to go
#
#
# You have scrapped 38 pages of apartment listings.
# You have 2338 listings left to go
#
#
# You have scrapped 39 pages of apartment listings.
# You have 2325 listings left to go
#
#
# You have scrapped 40 pages of apartment listings.
# You have 2290 listings left to go
#
#
# You have scrapped 41 pages of apartment listings.
# You have 2266 listings left to go
#
#
# We are scraping the borough named: ['Westminster']
# You have scrapped 1 pages of apartment listings.
# You have 4580 listings left to go
#
#
# You have scrapped 2 pages of apartment listings.
# You have 4556 listings left to go
#
#
# You have scrapped 3 pages of apartment listings.
# You have 4532 listings left to go
#
#
# You have scrapped 4 pages of apartment listings.
# You have 4508 listings left to go
#
#
# You have scrapped 5 pages of apartment listings.
# You have 4484 listings left to go
#
#
# You have scrapped 6 pages of apartment listings.
# You have 4460 listings left to go
#
#
# You have scrapped 7 pages of apartment listings.
# You have 4436 listings left to go
#
#
# You have scrapped 8 pages of apartment listings.
# You have 4412 listings left to go
#
#
# You have scrapped 9 pages of apartment listings.
# You have 4388 listings left to go
#
#
# You have scrapped 10 pages of apartment listings.
# You have 4366 listings left to go
#
#
# You have scrapped 11 pages of apartment listings.
# You have 4342 listings left to go
#
#
# You have scrapped 12 pages of apartment listings.
# You have 4316 listings left to go
#
#
# You have scrapped 13 pages of apartment listings.
# You have 4292 listings left to go
#
#
# You have scrapped 14 pages of apartment listings.
# You have 4268 listings left to go
#
#
# You have scrapped 15 pages of apartment listings.
# You have 4246 listings left to go
#
#
# You have scrapped 16 pages of apartment listings.
# You have 4220 listings left to go
#
#
# You have scrapped 17 pages of apartment listings.
# You have 4196 listings left to go
#
#
# You have scrapped 18 pages of apartment listings.
# You have 4174 listings left to go
#
#
# You have scrapped 19 pages of apartment listings.
# You have 4150 listings left to go
#
#
# You have scrapped 20 pages of apartment listings.
# You have 4124 listings left to go
#
#
# You have scrapped 21 pages of apartment listings.
# You have 4100 listings left to go
#
#
# You have scrapped 22 pages of apartment listings.
# You have 4076 listings left to go
#
#
# You have scrapped 23 pages of apartment listings.
# You have 4052 listings left to go
#
#
# You have scrapped 24 pages of apartment listings.
# You have 4028 listings left to go
#
#
# You have scrapped 25 pages of apartment listings.
# You have 4006 listings left to go
#
#
# You have scrapped 26 pages of apartment listings.
# You have 3980 listings left to go
#
#
# You have scrapped 27 pages of apartment listings.
# You have 3956 listings left to go
#
#
# You have scrapped 28 pages of apartment listings.
# You have 3932 listings left to go
#
#
# You have scrapped 29 pages of apartment listings.
# You have 3910 listings left to go
#
#
# You have scrapped 30 pages of apartment listings.
# You have 3884 listings left to go
#
#
# You have scrapped 31 pages of apartment listings.
# You have 3860 listings left to go
#
#
# You have scrapped 32 pages of apartment listings.
# You have 3836 listings left to go
#
#
# You have scrapped 33 pages of apartment listings.
# You have 3812 listings left to go
#
#
# You have scrapped 34 pages of apartment listings.
# You have 3788 listings left to go
#
#
# You have scrapped 35 pages of apartment listings.
# You have 3764 listings left to go
#
#
# You have scrapped 36 pages of apartment listings.
# You have 3740 listings left to go
#
#
# You have scrapped 37 pages of apartment listings.
# You have 3718 listings left to go
#
#
# You have scrapped 38 pages of apartment listings.
# You have 3692 listings left to go
#
#
# You have scrapped 39 pages of apartment listings.
# You have 3668 listings left to go
#
#
# You have scrapped 40 pages of apartment listings.
# You have 3644 listings left to go
#
#
# You have scrapped 41 pages of apartment listings.
# You have 3620 listings left to go

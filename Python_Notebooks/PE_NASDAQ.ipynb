# %%
import pandas as pd

# %%
df = pd.read_csv('PE_NASDAQ.csv')

# %%
df.head(3)
# Out:
#          Date  Value
# 0  01/01/2003  22.90
# 1  01/12/2002  23.10
# 2  01/11/2002  23.35

# %%
df.rename(columns={'Value': 'Shiller PE Ratio'}, inplace=True)

# %%
df.head(50)
# Out:
#           Date  Shiller PE Ratio
# 0   01/01/2003             22.90
# 1   01/12/2002             23.10
# 2   01/11/2002             23.35
# 3   01/10/2002             21.96
# 4   01/09/2002             22.36
# 5   01/08/2002             23.59
# 6   01/07/2002             23.46
# 7   01/06/2002             26.39
# 8   01/05/2002             28.13
# 9   01/04/2002             29.01
# 10  01/03/2002             30.29
# 11  01/02/2002             29.09
# 12  01/01/2002             30.28
# 13  01/12/2001             30.50
# 14  01/11/2001             30.01
# 15  01/10/2001             28.58
# 16  01/09/2001             27.67
# 17  01/08/2001             31.40
# 18  01/07/2001             32.16
# 19  01/06/2001             33.07
# 20  01/05/2001             34.07
# 21  01/04/2001             32.17
# 22  01/03/2001             32.32
# 23  01/02/2001             35.83
# 24  01/01/2001             36.98
# 25  01/12/2000             37.27
# 26  01/11/2000             38.78
# ...

# %%
exported_values = list( df.T.to_dict().values() )

# %%
import json

# %%
# json.dumps(exported_values)

# %%
open('PE_NASDAQ.json','w').write(json.dumps(exported_values))
# Out:
# 16594

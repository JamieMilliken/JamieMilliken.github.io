# %%
import pandas as pd

# %%
df0 = pd.read_csv('Chart1data.csv')

# %%
df0.head(5)
# Out:
#    All property types  Detached houses  Semi-detached houses  Terraced houses  \
# 0              123002           261720                154879           119887
# 1              125792           267166                158051           123329
# 2              127918           265355                159147           124726
# 3              130411           280980                165413           127833
# 4              132705           279796                165391           129708
#
#    Flats and maisonettes        Date
# 0                 109870  1999-10-01
# 1                 111981  1999-11-01
# 2                 115071  1999-12-01
# 3                 115506  2000-01-01
# 4                 118641  2000-02-01

# %%
df1 = df0.set_index(['Date'])

# %%
df2 = df1.stack().reset_index()

# %%
df3 = df2.rename(columns={'level_1':'Property Type',0:'Price' })

# %%
df3.head(4)
# Out:
#          Date         Property Type   Price
# 0  1999-10-01    All property types  123002
# 1  1999-10-01       Detached houses  261720
# 2  1999-10-01  Semi-detached houses  154879
# 3  1999-10-01       Terraced houses  119887

# %%
df3.to_csv("Chart1data_final.csv")

# %%
import pandas as pd

# %%
df = pd.read_csv('US10Yr.csv')

# %%
df.head(4)
# Out:
#          DATE DGS10
# 0  1995-11-16  5.93
# 1  1995-11-17  5.92
# 2  1995-11-20  5.93
# 3  1995-11-21  5.92

# %%
df.rename(columns={'DATE': 'Date', 'DGS10': 'Yield'}, inplace=True)

# %%
df.head(2)
# Out:
#          Date Yield
# 0  1995-11-16  5.93
# 1  1995-11-17  5.92

# %%
exported_values = list( df.T.to_dict().values() )

# %%
import json

# %%
# json.dumps(exported_values)

# %%
open('US10Yr.json','w').write(json.dumps(exported_values))
# Out:
# 74682
